# %% [markdown]
# <a href="https://colab.research.google.com/github/AnweshaPatra/advanced-dbms/blob/main/fake_instagram_profile_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Accuracy

from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,accuracy_score,roc_curve,confusion_matrix

# %%
# Load the training dataset
instagram_df_train=pd.read_csv('train.csv')
instagram_df_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 0                 0                  53             0        0      32
# 1                 0                  44             0        0     286
# 2                 0                   0             0        1      13
# 3                 0                  82             0        0     679
# 4                 0                   0             0        1       6
# ..              ...                 ...           ...      ...     ...
# 571               0                   0             0        0      33
# 572               0                  21             0        0      44
# 573               0                   0             0        0       4
# 574               0                  11             0        0       0
# 575               0                   0             0        0       2
#
#      #followers  #follows  fake
# 0          1000       955     0
# 1          2740       533     0
# 2           159        98     0
# 3           414       651     0
# 4           151       126     0
# ..          ...       ...   ...
# 571         166       596     1
# 572          66        75     1
# 573          96       339     1
# 574          57        73     1
# 575         150       487     1
#
# [576 rows x 12 columns]

# %%
# Load the testing data
instagram_df_test=pd.read_csv('test.csv')
instagram_df_test
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 0                 1                  30             0        1      35
# 1                 0                  64             0        1       3
# 2                 0                  82             0        1     319
# 3                 0                 143             0        1     273
# 4                 0                  76             0        1       6
# ..              ...                 ...           ...      ...     ...
# 115               0                   0             0        0      13
# 116               0                   0             0        0       4
# 117               0                   0             0        0       3
# 118               0                   0             0        0       1
# 119               0                   0             0        0       3
#
#      #followers  #follows  fake
# 0           488       604     0
# 1            35         6     0
# 2           328       668     0
# 3         14890      7369     0
# 4           225       356     0
# ..          ...       ...   ...
# 115         114       811     1
# 116         150       164     1
# 117         833      3572     1
# 118         219      1695     1
# 119          39        68     1
#
# [120 rows x 12 columns]

# %%
# Training and testing dataset (inputs)
X_train = instagram_df_train.drop(columns = ['fake'])
X_test = instagram_df_test.drop(columns = ['fake'])
X_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 0                 0                  53             0        0      32
# 1                 0                  44             0        0     286
# 2                 0                   0             0        1      13
# 3                 0                  82             0        0     679
# 4                 0                   0             0        1       6
# ..              ...                 ...           ...      ...     ...
# 571               0                   0             0        0      33
# 572               0                  21             0        0      44
# 573               0                   0             0        0       4
# 574               0                  11             0        0       0
# 575               0                   0             0        0       2
#
#      #followers  #follows
# 0          1000       955
# 1          2740       533
# 2           159        98
# 3           414       651
# 4           151       126
# ..          ...       ...
# 571         166       596
# 572          66        75
# 573          96       339
# 574          57        73
# 575         150       487
#
# [576 rows x 11 columns]

# %%
# Training and testing dataset (Outputs)
y_train = instagram_df_train['fake']
y_test = instagram_df_test['fake']
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 571    1
# 572    1
# 573    1
# 574    1
# 575    1
# Name: fake, Length: 576, dtype: int64

# %%
# Scale the data before training the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X_train = scaler_x.fit_transform(X_train)
X_test = scaler_x.transform(X_test)

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes = 2)
y_test = tf.keras.utils.to_categorical(y_test, num_classes = 2)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(50, input_dim=11, activation='relu'))
model.add(Dense(150, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(150, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(25, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(2,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                600
#
#  dense_1 (Dense)             (None, 150)               7650
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_3 (Dense)             (None, 25)                3775
#
#  dropout_2 (Dropout)         (None, 25)                0
#
#  dense_4 (Dense)             (None, 2)                 52
#
# =================================================================
# Total params: 34,727
# Trainable params: 34,727
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 50,  verbose = 1, validation_split = 0.1)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 2s 17ms/step - loss: 0.6020 - accuracy: 0.7066 - val_loss: 0.5385 - val_accuracy: 0.8621
# Epoch 2/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4065 - accuracy: 0.8745 - val_loss: 0.2815 - val_accuracy: 0.8966
# Epoch 3/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3083 - accuracy: 0.8977 - val_loss: 0.2010 - val_accuracy: 0.8793
# Epoch 4/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2705 - accuracy: 0.9035 - val_loss: 0.1337 - val_accuracy: 0.9655
# Epoch 5/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2650 - accuracy: 0.8958 - val_loss: 0.2386 - val_accuracy: 0.8793
# Epoch 6/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2582 - accuracy: 0.8996 - val_loss: 0.1670 - val_accuracy: 0.9138
# Epoch 7/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2363 - accuracy: 0.9208 - val_loss: 0.1871 - val_accuracy: 0.9138
# Epoch 8/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2302 - accuracy: 0.9189 - val_loss: 0.2294 - val_accuracy: 0.8793
# Epoch 9/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2128 - accuracy: 0.9208 - val_loss: 0.1764 - val_accuracy: 0.8966
# Epoch 10/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2156 - accuracy: 0.9151 - val_loss: 0.1920 - val_accuracy: 0.8966
# Epoch 11/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2066 - accuracy: 0.9247 - val_loss: 0.2021 - val_accuracy: 0.8793
# Epoch 12/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2308 - accuracy: 0.9189 - val_loss: 0.2302 - val_accuracy: 0.8793
# Epoch 13/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 0.9208 - val_loss: 0.1617 - val_accuracy: 0.9138
# Epoch 14/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2106 - accuracy: 0.9228 - val_loss: 0.2078 - val_accuracy: 0.8966
# Epoch 15/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1890 - accuracy: 0.9189 - val_loss: 0.2400 - val_accuracy: 0.8793
# Epoch 16/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1749 - accuracy: 0.9286 - val_loss: 0.2080 - val_accuracy: 0.9138
# Epoch 17/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.9247 - val_loss: 0.2427 - val_accuracy: 0.9138
# Epoch 18/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1716 - accuracy: 0.9305 - val_loss: 0.2077 - val_accuracy: 0.9138
# Epoch 19/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1737 - accuracy: 0.9305 - val_loss: 0.1938 - val_accuracy: 0.9138
# Epoch 20/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1770 - accuracy: 0.9324 - val_loss: 0.3066 - val_accuracy: 0.8793
# Epoch 21/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1717 - accuracy: 0.9189 - val_loss: 0.2590 - val_accuracy: 0.8966
# Epoch 22/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1496 - accuracy: 0.9286 - val_loss: 0.2989 - val_accuracy: 0.8793
# Epoch 23/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1558 - accuracy: 0.9402 - val_loss: 0.3289 - val_accuracy: 0.8621
# Epoch 24/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1647 - accuracy: 0.9305 - val_loss: 0.2847 - val_accuracy: 0.8966
# Epoch 25/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1659 - accuracy: 0.9344 - val_loss: 0.2454 - val_accuracy: 0.9138
# Epoch 26/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1537 - accuracy: 0.9363 - val_loss: 0.2427 - val_accuracy: 0.9138
# Epoch 27/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1581 - accuracy: 0.9324 - val_loss: 0.2568 - val_accuracy: 0.8966
# Epoch 28/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1485 - accuracy: 0.9479 - val_loss: 0.2109 - val_accuracy: 0.9138
# Epoch 29/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9344 - val_loss: 0.3297 - val_accuracy: 0.8793
# Epoch 30/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1446 - accuracy: 0.9382 - val_loss: 0.2537 - val_accuracy: 0.9138
# Epoch 31/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1450 - accuracy: 0.9363 - val_loss: 0.3283 - val_accuracy: 0.8793
# Epoch 32/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1446 - accuracy: 0.9517 - val_loss: 0.2709 - val_accuracy: 0.9138
# Epoch 33/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1312 - accuracy: 0.9440 - val_loss: 0.3656 - val_accuracy: 0.8793
# Epoch 34/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1433 - accuracy: 0.9421 - val_loss: 0.2493 - val_accuracy: 0.9138
# Epoch 35/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9537 - val_loss: 0.3412 - val_accuracy: 0.8966
# Epoch 36/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1256 - accuracy: 0.9537 - val_loss: 0.3132 - val_accuracy: 0.9138
# Epoch 37/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1324 - accuracy: 0.9402 - val_loss: 0.4870 - val_accuracy: 0.8448
# Epoch 38/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1278 - accuracy: 0.9517 - val_loss: 0.3948 - val_accuracy: 0.8793
# Epoch 39/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.9498 - val_loss: 0.1968 - val_accuracy: 0.9310
# Epoch 40/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.9440 - val_loss: 0.4992 - val_accuracy: 0.8448
# Epoch 41/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9498 - val_loss: 0.4032 - val_accuracy: 0.8793
# Epoch 42/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1247 - accuracy: 0.9517 - val_loss: 0.4119 - val_accuracy: 0.8793
# Epoch 43/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1099 - accuracy: 0.9479 - val_loss: 0.2862 - val_accuracy: 0.9138
# Epoch 44/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1230 - accuracy: 0.9498 - val_loss: 0.4407 - val_accuracy: 0.8793
# Epoch 45/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1221 - accuracy: 0.9498 - val_loss: 0.4252 - val_accuracy: 0.8966
# Epoch 46/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 0.9459 - val_loss: 0.3722 - val_accuracy: 0.8966
# Epoch 47/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1313 - accuracy: 0.9459 - val_loss: 0.4314 - val_accuracy: 0.8621
# Epoch 48/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1159 - accuracy: 0.9537 - val_loss: 0.3318 - val_accuracy: 0.8793
# Epoch 49/50
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1232 - accuracy: 0.9498 - val_loss: 0.3402 - val_accuracy: 0.8966
# Epoch 50/50
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1077 - accuracy: 0.9537 - val_loss: 0.3775 - val_accuracy: 0.8793

# %%
print(epochs_hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progression During Training/Validation')
plt.ylabel('Training and Validation Losses')
plt.xlabel('Epoch Number')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()

# %%
predicted = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
predicted_value = []
test = []
for i in predicted:
    predicted_value.append(np.argmax(i))
    
for i in y_test:
    test.append(np.argmax(i))

# %%
print(classification_report(test, predicted_value))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89        60
#            1       0.89      0.90      0.89        60
#
#     accuracy                           0.89       120
#    macro avg       0.89      0.89      0.89       120
# weighted avg       0.89      0.89      0.89       120

# %%
plt.figure(figsize=(10, 10))
cm=confusion_matrix(test, predicted_value)
sns.heatmap(cm, annot=True)
plt.show()
